# %%
import numpy as np
from pylab import *

from astropy.io import fits

# %%
ff = fits.open("c://users//npk//downloads/sdR-s-sp1-00000199.fits.gz")

# %%
phdu = ff[1]
D = phdu.data

# %%
phdu.header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4120
# NAXIS2  =                 4080
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# BSCALE  =                    1
# BZERO   =                32768
# SPEC    = 'sp1     '
# OBSTIME = '2021-05-07T02:26:54.107' / Start of the observation
# EXPTIME =                  0.0
# IMAGETYP= 'bias    '
# INTSTART= '2021-05-07T02:26:54.107' / Start of the integration
# INTEND  = '2021-05-07T03:49:16.082' / End of the integration
# CCD     = 'r1      '
# CCDTEMP =          -110.000256 / Temperature of the sensor (HEATERX 2)
# LABTEMP =              23.9478 / Govee H5179 lab temperature [C]
# LABHUMID=                 47.8 / Govee H5179 lab humidity [%]
# PRESURE =             6.81E-05 / Spectrograph pressure [torr]
# ...

# %%
D.shape
# Out:
# (4080, 4120)

# %%
imshow(D[300:800,100:2000])
colorbar()

# %%
D.shape
# Out:
# (4080, 4120)

# %%
q1x = slice(0,4080//2)
q1y = slice(0,4120//2)

# %%
q1=D[q1x, q1y]

# %%
imshow(q1)

# %%
rr = range(4)
for i in rr:
    plot(q1[:,i])
    print(np.mean(q1[:,i]))

legend(list(rr))
# Out:
# 3238.4470588235295
# 2102.0941176470587
# 2103.7426470588234
# 36117.88137254902

# %%
q1.shape
# Out:
# (2040, 2060)

# %%
q1.shape
# Out:
# (2040, 2060)

# %%
rr = range(15)
for i in rr:
    s = 2060-i-1
    plot(q1[:,s])
    print(np.mean(q1[:,s]), np.std(q1[:,s]))

legend(list(rr))
# Out:
# 2076.412745098039 11.55210847038304
# 2076.7975490196077 11.603865729792295
# 2076.0833333333335 11.716291517716028
# 2076.8058823529414 11.87630548885429
# 2076.8632352941177 11.66620816985038
# 2075.9362745098038 11.467766327933935
# 2076.755392156863 11.60571488463627
# 2076.2975490196077 11.311376967224454
# 2076.7127450980392 11.783206490999588
# 2076.5446078431373 11.570541124123647
# 2076.3485294117645 11.619228392006312
# 2076.518137254902 11.886417708542194
# 2076.130392156863 11.788481327256525
# 2076.741666666667 11.539167280872034
# 2080.677450980392 11.727915473162156

# %%
11.7/3
# Out:
# 3.9
